# %% [markdown]
# # Autoencoder for MNIST
#
# Welcome to this notebook where you'll be training an autoencoder using the MNIST dataset, which comprises handwritten digits. This exercise is the last where we present you with a structured skeleton to work with. However, in following exercises, we will only provide you with the dataset, task, and a test scenario, enabling you to test your skills and compete with your peers on our leaderboards. Get ready to dive in and showcase your deep learning expertise!
#
#
# ## Your task:
#
# Autoencoders have various applications, including unsupervised pretraining using unlabeled data, followed by fine-tuning the encoder with labeled data. This approach can greatly enhance performance when there is only a little amount of labeled data but a lot of unlabeled data available.
#
# In this exercise, you will use the MNIST dataset, consisting of 60,000 images of handwritten digits. However, not all the image labels are available to you. Your first objective is to train an autoencoder to accurately reproduce these unlabeled images.
#
# Afterwards, you will transfer the weights of the pretrained encoder and perform fine-tuning on a classifier using the available labeled data. This technique is commonly known as **transfer learning**, which allows you to leverage the knowledge gained from the autoencoder to improve the classification of the handwritten digits.

# %%
# For automatic file reloading as usual
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## (Optional) Mount folder in Colab
#
# Uncomment the following cell to mount your gdrive if you are using the notebook in google colab:

# %%
# Use the following lines if you want to use Google Colab
# We presume you created a folder "i2dl" within your main drive folder, and put the exercise there.
# NOTE: terminate all other colab sessions that use GPU!
# NOTE 2: Make sure the correct exercise folder (e.g exercise_08) is given.

# from google.colab import drive
# import os

"""
from google.colab import drive
import os
gdrive_path='/content/gdrive/MyDrive/i2dl/exercise_08'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
"""
# Out:
# "\nfrom google.colab import drive\nimport os\ngdrive_path='/content/gdrive/MyDrive/i2dl/exercise_08'\n\n# This will mount your google drive under 'MyDrive'\ndrive.mount('/content/gdrive', force_remount=True)\n# In order to access the files in this notebook we have to navigate to the correct folder\nos.chdir(gdrive_path)\n# Check manually if all files are present\n"

# %% [markdown]
# ### Set up PyTorch environment in colab
# - (OPTIONAL) Enable GPU via Runtime --> Change runtime type --> GPU
# - Uncomment the following cell if you are using the notebook in google colab:

# %%
# Optional: install correct libraries in google colab
# !python -m pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchtext==0.12.0+cu113 torchaudio==0.12.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html
# !python -m pip install tensorboard==2.8.0 > /dev/null
# !python -m pip install pytorch-lightning==1.6.0

# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import os, sys
import shutil
import torch
import torch.nn as nn
from torchvision import transforms
from exercise_code.image_folder_dataset import ImageFolderDataset
from torch.utils.tensorboard import SummaryWriter
from time import sleep
from tqdm import tqdm
from exercise_code.tests.base_tests import bcolors

torch.manual_seed(42)

os.environ['KMP_DUPLICATE_LIB_OK']='True' # To prevent the kernel from dying.

# %% [markdown]
# <div class="alert alert-warning">
#     <h3>Note: Google Colab</h3>
#     <p>
# In case you don't have a GPU, you can run this notebook on Google Colab where you can access a GPU for free, but, of course, you can also run this notebook on your CPU.
#          </p>
# </div>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('You are using the following device: ', device)
# Out:
# You are using the following device:  cpu

# %% [markdown]
# ## Setup TensorBoard
#
# In the previous exercise (Exercise 07), you learned how to use TensorBoard effectively. Let's use it again to enhance the convenience of debugging your network and the training process. Throughout this notebook, feel free to implement additional logs or visualizations into your TensorBoard, further improving your analysis and understanding of the network's behavior.

# %%
################# COLAB ONLY #################
# %load_ext tensorboard
# %tensorboard --logdir=./ --port 6006

# Use the cmd for less trouble, if you can. From the working directory, run: tensorboard --logdir=./ --port 6006

# %% [markdown]
# # 1. The MNIST Dataset
#
# First, let's download the MNIST dataset. As mentioned in the beginning of this notebook, MNIST is a dataset of 60,000 images depicting handwritten digits. However, labeling such a large dataset can be a costly process, leaving us in a challenging situation.
#
# To overcome this, a practical approach is to label a small subset of the images. Let's consider a scenario where you have hired another student to perform the labeling task for you. After some time, you have been provided with 300 labeled images. Out of these, 100 images will be used for training, another 100 for validation, and the remaining 100 for testing. Undoubtedly, this poses a challenge due to the limited number of labeled samples.
#
# Now, you have the flexibility to define any transforms that you deem necessary, either at this point or at a later stage. However, it's important to note that during the final evaluation on the server, no transformations will be applied to the test set.
#
# Feel free to experiment with various transforms as you proceed (you can also pass without any transforms).
#
#
# **Note**: We do **not** apply any transformations to the test set at the time of final evaluation on our server.

# %%
transform = transforms.Compose([])

########################################################################
# TODO: Feel free to define transforms                                 #
########################################################################
transform = transforms.Compose([transforms.ToPILImage(),
                                transforms.RandomAffine(0,shear=30,scale=[1.15,1.15]),
                                transforms.RandomRotation(10),
                                transforms.ToTensor(),
                                transforms.Normalize((0.1307), (0.3081))]
                              )




########################################################################
#                           END OF YOUR CODE                           #
########################################################################

i2dl_exercises_path = os.path.dirname(os.path.abspath(os.getcwd()))
mnist_root = os.path.join(i2dl_exercises_path, "datasets", "mnist")

train_100_dataset = ImageFolderDataset(root=mnist_root,images='train_images.pt',labels='train_labels.pt',force_download=False,verbose=True,transform=transform)
val_100_dataset = ImageFolderDataset(root=mnist_root,images='val_images.pt',labels='val_labels.pt',force_download=False,verbose=True,transform=transform)
test_100_dataset = ImageFolderDataset(root=mnist_root,images='test_images.pt',labels='test_labels.pt',force_download=False,verbose=True,transform=transform)

# We also set up the unlabeled images which we will use later
unlabeled_train = ImageFolderDataset(root=mnist_root,images='unlabeled_train_images.pt',force_download=False,verbose=True,transform=transform)
unlabeled_val = ImageFolderDataset(root=mnist_root,images='unlabeled_val_images.pt',force_download=False,verbose=True,transform=transform)
# Out:
# Found dataset folder. Skipped downloading. If you face issues, please re-download the dataset using
# '--force_download=True'
# https://i2dl.vc.in.tum.de/static/data/mnist.zip
# Found dataset folder. Skipped downloading. If you face issues, please re-download the dataset using
# '--force_download=True'
# https://i2dl.vc.in.tum.de/static/data/mnist.zip
# Found dataset folder. Skipped downloading. If you face issues, please re-download the dataset using
# '--force_download=True'
# https://i2dl.vc.in.tum.de/static/data/mnist.zip
# Found dataset folder. Skipped downloading. If you face issues, please re-download the dataset using
# '--force_download=True'
# https://i2dl.vc.in.tum.de/static/data/mnist.zip
# Found dataset folder. Skipped downloading. If you face issues, please re-download the dataset using
# '--force_download=True'
# https://i2dl.vc.in.tum.de/static/data/mnist.zip

# %% [markdown]
# The dataset consists of tuples of 28x28 pixel PIL images and a label that is an integer from 0 to 9.
#
# Let's turn a few of the images into numpy arrays, to look at their shape and visualize them and see if the labels we paid for are correct.

# %%
plt.rcParams['figure.figsize'] = (16,16) # Make the figures a bit bigger

indices_arr = [83, 98, 92, 99, 78, 97, 90, 95, 93, 96]
for i, index in enumerate(indices_arr):
    image = np.array(train_100_dataset[index][0].squeeze()) # get the image of the data sample
    label = train_100_dataset[index][1] # get the label of the data sample
    plt.subplot(1, 10, i + 1)
    plt.imshow(image, cmap='gray', interpolation='none')
    plt.title("Class {}".format(label))
    
plt.tight_layout()
print('The shape of our greyscale images: ', image.shape)
# Out:
# The shape of our greyscale images:  (28, 28)

# %% [markdown]
# <div class="alert alert-warning">
#     <h3>Note: Starting Simple</h3>
#     <p>
# Regardless of the size of the dataset, the first step is to evaluate the performance of a simple classifier. It is advisable to always start with a straightforward approach when tackling a problem and gradually build upon it to determine which changes yield improvements.</p>
# </div>
#
# # 2. A Simple Classifier
#
# In `exercise_code/models.py` we prepared all classes for you which you will finalize throughout the notebook to build an Autoencoder and an image classifier with PyTorch.
#
# ![network_split](img/network_split.png)
#
# ## 2.1 The Encoder
#
# Unlike to previous models, we are going to split up the model into two parts: the `encoder` and the `classifier`. The `classifier` has a fixed task, generating predictions given a one-dimensional input. On the other hand, the `encoder`'s task is to extract meaningful information from the input, enabling the classifier to make accurate decisions.
#
# For now, both networks will be similar in design and consist of linear layers coupled with auxiliary layers. This split-up will be relevant later, e.g., by using convolutional layers which are introduced in the lecture. We are going to set up the `encoder` now.
#
# Think about a good network architecture. You have complete freedom in this regard and can devise any network structure that you think might be fitting. (\*)
#
# Have a look at the documentation of `torch.nn` at https://pytorch.org/docs/stable/nn.html to learn how to use this module in order to build your network!
#
# Then implement your architecture: initialize it in `__init__()` and assign it to `self.model`. This is particularly easy using `nn.Sequential()` where you only have to pass the list of your layers.
#
# To make your model customizable and support parameter search, do not use hardcoded hyperparameters - instead, pass them as a simple dictionary `hparams` (here, `n_hidden` is the number of neurons in the hidden layer) when initializing `models`.
#
# Here is an simple example:
#
# ```python
#         self.model = nn.Sequential(
#             nn.Linear(input_size, self.hparams["n_hidden"]),
#             nn.ReLU(),
#             nn.Linear(self.hparams["n_hidden"], num_classes)
#         )
# ```
#
# Have a look at the forward path in `forward(self, x)`, which is so easy that you don't need to implement it yourself.
#
# As PyTorch automatically computes the gradients, that's all you need to do! No need to manually calculate derivatives for the backward paths anymore! :)
#
#
# ____
# \* *The size of your final model must be less than 20 MB, which is approximately equivalent to 5 Mio. params. Note that this limit is quite lenient, you will probably need much less parameters!*
#
# *In order to keep things simple, you should only use fully connected layers for this task as we need to revert the encoder architecture  later on in the notebook.*
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Implement the <code>Encoder</code> class initialization in <code>exercise_code/models.py</code>.
#     </p>
# </div>

# %% [markdown]
# ## 2.2 The Classifier
#
# Now let's implement the classifier. The classifier will utilize the encoder that you have defined in the above cell. By looking at `Classifier.forward`, you can see that we are essentially concatenating the `classifier`and the `encoder` together. Therefore, it is crucial to ensure that the input shape of the classifier matches the output shape of the encoder you implemented above
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>1. Implement the <code>Classifier</code> class network initialization in <code>exercise_code/models.py</code>.
#     </p>
#     <p>2. Define in the next cell your hyperparameters in a dictionary called 'hparams'.
#     </p>
# </div>

# %%
hparams = {}
########################################################################
# TODO: Define your hyper parameters here!                             #
########################################################################
hparams = {
    'batch_size': 64,
    'learning_rate': 1e-2,
    'epochs': 10
}

########################################################################
#                           END OF YOUR CODE                           #
########################################################################

# %% [markdown]
# ## 2.3 Optimizer
# Lastly, implement the function `set_optimizer` to define your optimizer. Here the documentation of `torch.optim` at https://pytorch.org/docs/stable/optim.html might be helpful.
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Implement the <code>set_optimizer</code> method of the <code>Classifier</code> in <code>exercise_code/models.py</code>.
#     </p>
# </div>

# %% [markdown]
# ## 2.4 Training & Validation Step
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p> Let's take a closer look at the training pipeline outlined below. It is explicitly written here in its entirety to provide you with a comprehensive understanding of its structure. Additionally, you can refer back to this pipeline whenever you encounter any uncertainties or need guidance.
#  </p>
# </div>

# %%
 # One of the most crucial things in deep learning is to understand the training pipeline:
 # 1. Forward()          --> The forward pass of the network, to calculate the currnent loss.
 # 2. Backward()         --> The backward pass of the network, to calculate the gradients w.r.t the loss, calculated in the previous stage.
 # 3. Optimizer_step()   --> Update the weights w.r.t thier corresponding gradients and the learnign rate.

def create_tqdm_bar(iterable, desc):
    return tqdm(enumerate(iterable),total=len(iterable), ncols=150, desc=desc)


def train_classifier(classifier, train_loader, val_loader, loss_func, tb_logger, epochs=10, name="default"):
    """
    Train the classifier for a number of epochs.
    """
    optimizer = classifier.optimizer
    classifier = classifier.to(device)
    for epoch in range(epochs):
        
        training_loss = 0
        validation_loss = 0
        
        # Training stage, where we want to update the parameters.
        classifier.train()  # Set the model to training mode
        
        # Create a progress bar for the training loop.
        training_loop = create_tqdm_bar(train_loader, desc=f'Training Epoch [{epoch + 1}/{epochs}]')
        for train_iteration, batch in training_loop:
            optimizer.zero_grad() # Reset the gradients - VERY important! Otherwise they accumulate.
            images, labels = batch # Get the images and labels from the batch, in the fashion we defined in the dataset and dataloader.
            images, labels = images.to(device), labels.to(device) # Send the data to the device (GPU or CPU) - it has to be the same device as the model.

            # Flatten the images to a vector. This is done because the classifier expects a vector as input.
            # Could also be done by reshaping the images in the dataset.
            images = images.view(images.shape[0], -1) 

            pred = classifier(images) # Stage 1: Forward().
            loss = loss_func(pred, labels) # Compute the loss over the predictions and the ground truth.
            loss.backward()  # Stage 2: Backward().
            optimizer.step() # Stage 3: Update the parameters.

            training_loss += loss.item()

            # Update the progress bar.
            training_loop.set_postfix(curr_train_loss = "{:.8f}".format(training_loss / (train_iteration + 1)), val_loss = "{:.8f}".format(validation_loss))

            # Update the tensorboard logger.
            tb_logger.add_scalar(f'classifier_{name}/train_loss', loss.item(), epoch * len(train_loader) + train_iteration)
            sleep(0.1) # Remove this line if you want to see the progress bar faster.

        # Validation stage, where we don't want to update the parameters. Pay attention to the classifier.eval() line
        # and "with torch.no_grad()" wrapper.
        classifier.eval()
        val_loop = create_tqdm_bar(val_loader, desc=f'Validation Epoch [{epoch + 1}/{epochs}]')
        validation_loss = 0
        with torch.no_grad():
            for val_iteration, batch in val_loop:
                images, labels = batch
                images, labels = images.to(device), labels.to(device)

                images = images.view(images.shape[0], -1) 
                pred = classifier(images)
                loss = loss_func(pred, labels)
                validation_loss += loss.item()

                # Update the progress bar.
                val_loop.set_postfix(val_loss = "{:.8f}".format(validation_loss / (val_iteration + 1)))

                # Update the tensorboard logger.
                tb_logger.add_scalar(f'classifier_{name}/val_loss', loss.item(), epoch * len(val_loader) + val_iteration)
                sleep(0.1) # Remove this line if you want to see the progress bar faster.
        
        # This value is used for the progress bar of the training loop.
        validation_loss /= len(val_loader)

# %% [markdown]
# ## 2.5 Fit Classification Model with Trainer
# Now it's finally time to train your model.
# Run the following cell to see the behold the magic of deep learning at play.

# %%
from exercise_code.models import Classifier
from exercise_code.models import Encoder

# Create the encoder and the classifier.
encoder = Encoder(hparams).to(device)
classifier = Classifier(hparams, encoder).to(device)

# Create a tensorboard logger.
# NOTE: In order to see the logs, run the following command in the terminal: tensorboard --logdir=./
# Also, in order to reset the logs, delete the logs folder MANUALLY.

path = os.path.join('logs', 'cls_logs')
num_of_runs = len(os.listdir(path)) if os.path.exists(path) else 0
path = os.path.join(path, f'run_{num_of_runs + 1}')

tb_logger = SummaryWriter(path)

# Train the classifier.
labled_train_loader = torch.utils.data.DataLoader(train_100_dataset, batch_size=hparams['batch_size'], shuffle=True)
labled_val_loader = torch.utils.data.DataLoader(val_100_dataset, batch_size=hparams['batch_size'], shuffle=False)

epochs = hparams.get('epochs', 10)
loss_func = nn.CrossEntropyLoss() # The loss function we use for classification.
train_classifier(classifier, labled_train_loader, labled_val_loader, loss_func, tb_logger, epochs=epochs, name="Default")

print("Finished training!")
print("How did we do? Let's check the accuracy of the defaut classifier on the training and validation sets:")
print(f"Training Acc: {classifier.getAcc(labled_train_loader)[1] * 100}%")
print(f"Validation Acc: {classifier.getAcc(labled_val_loader)[1] * 100}%")
# Out:
# Training Epoch [1/10]:  50%|█████████████████████▌                     | 1/2 [00:00<00:00,  7.57it/s, curr_train_loss=2.24472356, val_loss=0.00000000]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/10]: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00,  7.65it/s, curr_train_loss=2.24472356, val_loss=0.00000000]
# Validation Epoch [1/10]:  50%|██████████████████████████████████▌                                  | 1/2 [00:00<00:00,  7.78it/s, val_loss=2.15924549]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [1/10]: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.63it/s, val_loss=2.15924549]
# Training Epoch [2/10]:  50%|█████████████████████▌                     | 1/2 [00:00<00:00,  6.89it/s, curr_train_loss=2.04369819, val_loss=0.00000000]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/10]: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00,  6.87it/s, curr_train_loss=2.04369819, val_loss=0.00000000]
# Validation Epoch [2/10]:  50%|██████████████████████████████████▌                                  | 1/2 [00:00<00:00,  7.20it/s, val_loss=2.07715738]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [2/10]: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  6.90it/s, val_loss=2.07715738]
# Training Epoch [3/10]:  50%|█████████████████████▌                     | 1/2 [00:00<00:00,  7.18it/s, curr_train_loss=1.89115041, val_loss=0.00000000]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/10]: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00,  6.97it/s, curr_train_loss=1.89115041, val_loss=0.00000000]
# Validation Epoch [3/10]:  50%|██████████████████████████████████▌                                  | 1/2 [00:00<00:00,  7.87it/s, val_loss=2.03296363]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [3/10]: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.58it/s, val_loss=2.03296363]
# Training Epoch [4/10]:  50%|█████████████████████▌                     | 1/2 [00:00<00:00,  7.11it/s, curr_train_loss=1.84021765, val_loss=0.00000000]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [4/10]: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00,  7.12it/s, curr_train_loss=1.84021765, val_loss=0.00000000]
# Validation Epoch [4/10]:  50%|██████████████████████████████████▌                                  | 1/2 [00:00<00:00,  7.22it/s, val_loss=2.01192129]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [4/10]: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.45it/s, val_loss=2.01192129]
# Training Epoch [5/10]:  50%|█████████████████████▌                     | 1/2 [00:00<00:00,  7.20it/s, curr_train_loss=1.76933020, val_loss=0.00000000]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [5/10]: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00,  7.04it/s, curr_train_loss=1.76933020, val_loss=0.00000000]
# Validation Epoch [5/10]:  50%|██████████████████████████████████▌                                  | 1/2 [00:00<00:00,  7.83it/s, val_loss=1.98395610]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [5/10]: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.51it/s, val_loss=1.98395610]
# Training Epoch [6/10]:  50%|█████████████████████▌                     | 1/2 [00:00<00:00,  7.14it/s, curr_train_loss=1.73770517, val_loss=0.00000000]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [6/10]: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00,  7.06it/s, curr_train_loss=1.73770517, val_loss=0.00000000]
# Validation Epoch [6/10]:  50%|██████████████████████████████████▌                                  | 1/2 [00:00<00:00,  7.37it/s, val_loss=1.93897134]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [6/10]: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.43it/s, val_loss=1.93897134]
# Training Epoch [7/10]:  50%|█████████████████████▌                     | 1/2 [00:00<00:00,  7.47it/s, curr_train_loss=1.72575647, val_loss=0.00000000]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [7/10]: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00,  7.22it/s, curr_train_loss=1.72575647, val_loss=0.00000000]
# Validation Epoch [7/10]:  50%|██████████████████████████████████▌                                  | 1/2 [00:00<00:00,  7.37it/s, val_loss=1.79069191]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [7/10]: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.27it/s, val_loss=1.79069191]
# Training Epoch [8/10]:  50%|█████████████████████▌                     | 1/2 [00:00<00:00,  6.68it/s, curr_train_loss=1.68104720, val_loss=0.00000000]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [8/10]: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00,  6.97it/s, curr_train_loss=1.68104720, val_loss=0.00000000]
# Validation Epoch [8/10]:  50%|██████████████████████████████████▌                                  | 1/2 [00:00<00:00,  7.81it/s, val_loss=1.73007226]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [8/10]: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.67it/s, val_loss=1.73007226]
# Training Epoch [9/10]:  50%|█████████████████████▌                     | 1/2 [00:00<00:00,  7.29it/s, curr_train_loss=1.61567634, val_loss=0.00000000]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [9/10]: 100%|███████████████████████████████████████████| 2/2 [00:00<00:00,  7.16it/s, curr_train_loss=1.61567634, val_loss=0.00000000]
# Validation Epoch [9/10]:  50%|██████████████████████████████████▌                                  | 1/2 [00:00<00:00,  7.45it/s, val_loss=1.64099181]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [9/10]: 100%|█████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.37it/s, val_loss=1.64099181]
# Training Epoch [10/10]:  50%|█████████████████████                     | 1/2 [00:00<00:00,  7.11it/s, curr_train_loss=1.56616795, val_loss=0.00000000]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [10/10]: 100%|██████████████████████████████████████████| 2/2 [00:00<00:00,  7.20it/s, curr_train_loss=1.56616795, val_loss=0.00000000]
# Validation Epoch [10/10]:  50%|██████████████████████████████████                                  | 1/2 [00:00<00:00,  7.46it/s, val_loss=1.63610870]
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [10/10]: 100%|████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  7.41it/s, val_loss=1.63610870]
# Finished training!
# How did we do? Let's check the accuracy of the defaut classifier on the training and validation sets:
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Acc: 80.0%
# Shape of encoder torch.Size([64, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([36, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Acc: 52.0%

# %% [markdown]
# # 3. Autoencoder
#
# With only a limited number of labeled images, it's challenging to achieve high performance. We have no money left to pay the student to create more labels, and labeling the data ourselves is out of question. A commonly used approach would be to apply data augmentation to maximize the potential of our limited labeled data, but here we provide another way to solve this problem: **transfer learning**.
#
# For each input, the autoencoder tries to reproduce the same image as an output. The difficulty behind this task is that the autoencoder has to go through a low dimensional bottleneck, which is called the **latent space**.
# In other words, the autoencoder learns to represent all the input information in a low dimensional latent space - it learns to compress the input distribution. To train the autoencoder, we use the mean squared error loss, which calculates the discrepancy between the input pixels and the output pixels. The best part is that this loss function doesn't require any labels!
#
# By pretraining the autoencoder in this way on the large amount of unlabeled data, we can capture valuable latent representations of the input images. Then, we transfer the weights of the encoder to our classifier, enabling it to benefit from the knowledge learned during the unsupervised pretraining phase.
#
# ![autoencoder](img/autoencoder.png)
#
# After this, our encoder has learned to extract meaningful information from the inputs. We can then transfer its weights
# to a classifier architecture and finetune it with our labeled data, i.e., instead of initializing our encoder randomly we are re-using the weights of our trained encoder from our autoencoder network.
#
# ![autoencoder_pretrained](img/pretrained.png)
#
# ## 3.1 Decoder
#
# Before we can train our autoencoder, you have to initialize the your `decoder` architecture. The simplest way is to mirror your encoder architecture which ensure that the `latent space` output of our `encoder` is correctly transformed to our input shape.
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Implement the <code>Decoder</code> and <code>Autoencoder</code> class initialization in <code>exercise_code/models.py</code>.</p>
#     <p>Implemet <code>training_step</code> and <code>validation_step</code> of the autoencoder, following the pipeline we've shown you in train_classifier().</p>
#     <p>Note the differences between the classificaiton task, and now the regression task!</p>
#
#
# </div>
#
# ## 3.2 Autoencoder Training
#
# Now, we can train the full autoencoder consisting of both en- and decoder.

# %%
from exercise_code.models import Autoencoder, Encoder, Decoder

########################################################################
# TODO: Define your hyperparameters here!                              #
# Hint: use a large batch_size                                         #
########################################################################
hparams = {
            "epochs": 100,
            "batch_size": 4096,
            "hidden_dim": 200,
            "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"),
            "learning_rate": 0.01
          }

########################################################################
#                           END OF YOUR CODE                           #
########################################################################
encoder_pretrained = Encoder(hparams).to(device)
decoder = Decoder(hparams).to(device)
autoencoder = Autoencoder(hparams, encoder_pretrained, decoder).to(device)

# %% [markdown]
# Some tests to check whether we'll accept your model.

# %%
from exercise_code.Util import printModelInfo, load_model
_ = printModelInfo(autoencoder)
# Out:
# # Paramters: Your model has 0.892 mio. params.
# Model accepted!

# %% [markdown]
# After implementing the relevant functions - read the following code, and then run it.
# Keep in mind that an epoch here will take much longer since
# we are iterating through 5,8600 images instead of just 100.
#
# For speed, colab is indeed recommended.

# %%
encoder_pretrained = Encoder(hparams).to(device)
decoder = Decoder(hparams).to(device)
autoencoder = Autoencoder(hparams, encoder_pretrained, decoder).to(device)

def train_model(model, train_loader, val_loader, loss_func, tb_logger, epochs=10, name='Autoencoder'):
    
    optimizer = model.optimizer
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=epochs * len(train_loader) / 5, gamma=0.7)
    validation_loss = 0
    for epoch in range(epochs):
        
        # Train
        training_loop = create_tqdm_bar(train_loader, desc=f'Training Epoch [{epoch}/{epochs}]')
        for train_iteration, batch in training_loop:
            
            loss = model.training_step(batch, loss_func) # You need to implement this function.
            scheduler.step()

            # Update the progress bar.
            training_loop.set_postfix(curr_train_loss = "{:.8f}".format(loss.item()), val_loss = "{:.8f}".format(validation_loss))

            # Update the tensorboard logger.
            tb_logger.add_scalar(f'{name}/train_loss', loss.item(), epoch * len(train_loader) + train_iteration)

        # Validation
        val_loop = create_tqdm_bar(val_loader, desc=f'Validation Epoch [{epoch}/{epochs}]')
        validation_loss = 0
        with torch.no_grad():
            for val_iteration, batch in val_loop:
                loss = model.validation_step(batch, loss_func) # You need to implement this function.
                validation_loss += loss.item()

                # Update the progress bar.
                val_loop.set_postfix(curr_val_loss = "{:.8f}".format(loss.item()))

                # Update the tensorboard logger.
                tb_logger.add_scalar(f'{name}/val_loss', loss.item(), epoch * len(val_loader) + val_iteration)

        # This value is for the progress bar of the training loop.
        validation_loss /= len(val_loader)

# Creat a tensorboard logger.
# NOTE: In order to see the logs, run the following command in the terminal: tensorboard --logdir=./
# Also, in order to reset the logs, delete the logs folder MANUALLY.

path = os.path.join('logs', 'ae_logs')
num_of_runs = len(os.listdir(path)) if os.path.exists(path) else 0
path = os.path.join(path, f'run_{num_of_runs + 1}')
tb_logger = SummaryWriter(path)

# Train the classifier.
unlabled_train_loader = torch.utils.data.DataLoader(unlabeled_train, batch_size=hparams['batch_size'], shuffle=True)
unlabled_val_loader = torch.utils.data.DataLoader(unlabeled_val, batch_size=hparams['batch_size'], shuffle=False)

epochs = hparams.get('epochs', 5)
loss_func = nn.MSELoss() # The loss function we use for regression (Could also be nn.L1Loss()).
train_model(autoencoder, unlabled_train_loader, unlabled_val_loader, loss_func, tb_logger, epochs=epochs, name='Autoencoder')

print("Finished training!")
# Out:
# Training Epoch [0/100]:   0%|                                                                                                  | 0/15 [00:00<?, ?it/s]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:   7%|██▋                                      | 1/15 [00:01<00:18,  1.32s/it, curr_train_loss=1.57340443, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  13%|█████▍                                   | 2/15 [00:02<00:17,  1.31s/it, curr_train_loss=2.65083718, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  20%|████████▏                                | 3/15 [00:03<00:15,  1.26s/it, curr_train_loss=1.15654039, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  27%|██████████▉                              | 4/15 [00:05<00:13,  1.26s/it, curr_train_loss=1.13974965, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  33%|█████████████▋                           | 5/15 [00:06<00:12,  1.25s/it, curr_train_loss=1.31388080, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  40%|████████████████▍                        | 6/15 [00:07<00:11,  1.23s/it, curr_train_loss=1.34702384, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  47%|███████████████████▏                     | 7/15 [00:08<00:09,  1.22s/it, curr_train_loss=1.29357159, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  53%|█████████████████████▊                   | 8/15 [00:09<00:08,  1.20s/it, curr_train_loss=1.20543814, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  60%|████████████████████████▌                | 9/15 [00:11<00:07,  1.20s/it, curr_train_loss=1.11386800, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  67%|██████████████████████████▋             | 10/15 [00:12<00:06,  1.20s/it, curr_train_loss=1.06121385, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  73%|█████████████████████████████▎          | 11/15 [00:13<00:04,  1.20s/it, curr_train_loss=1.02434826, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  80%|████████████████████████████████        | 12/15 [00:14<00:03,  1.27s/it, curr_train_loss=0.98928839, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]:  87%|██████████████████████████████████▋     | 13/15 [00:16<00:02,  1.26s/it, curr_train_loss=0.97506124, val_loss=0.00000000]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [0/100]: 100%|████████████████████████████████████████| 15/15 [00:17<00:00,  1.18s/it, curr_train_loss=0.97149187, val_loss=0.00000000]
# Shape of encoder torch.Size([1256, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [0/100]: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.42it/s, curr_val_loss=1.27273273]
# Shape of encoder torch.Size([1000, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:   0%|                                                                                                  | 0/15 [00:00<?, ?it/s]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:   7%|██▋                                      | 1/15 [00:01<00:16,  1.21s/it, curr_train_loss=0.97747123, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  13%|█████▍                                   | 2/15 [00:02<00:15,  1.21s/it, curr_train_loss=0.97620058, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  20%|████████▏                                | 3/15 [00:03<00:14,  1.21s/it, curr_train_loss=0.96956092, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  27%|██████████▉                              | 4/15 [00:04<00:13,  1.19s/it, curr_train_loss=0.97287935, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  33%|█████████████▋                           | 5/15 [00:05<00:11,  1.18s/it, curr_train_loss=0.95404226, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  40%|████████████████▍                        | 6/15 [00:07<00:10,  1.18s/it, curr_train_loss=0.95116174, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  47%|███████████████████▏                     | 7/15 [00:08<00:09,  1.17s/it, curr_train_loss=0.95262039, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  53%|█████████████████████▊                   | 8/15 [00:09<00:08,  1.17s/it, curr_train_loss=0.95500791, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  60%|████████████████████████▌                | 9/15 [00:10<00:07,  1.17s/it, curr_train_loss=0.93911928, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  67%|██████████████████████████▋             | 10/15 [00:11<00:05,  1.16s/it, curr_train_loss=0.94137317, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  73%|█████████████████████████████▎          | 11/15 [00:12<00:04,  1.17s/it, curr_train_loss=0.93145227, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  80%|████████████████████████████████        | 12/15 [00:14<00:03,  1.20s/it, curr_train_loss=0.92699003, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]:  87%|██████████████████████████████████▋     | 13/15 [00:15<00:02,  1.19s/it, curr_train_loss=0.92767507, val_loss=1.27273273]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/100]: 100%|████████████████████████████████████████| 15/15 [00:16<00:00,  1.13s/it, curr_train_loss=0.93323272, val_loss=1.27273273]
# Shape of encoder torch.Size([1256, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [1/100]: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.65it/s, curr_val_loss=0.90599823]
# Shape of encoder torch.Size([1000, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:   0%|                                                                                                  | 0/15 [00:00<?, ?it/s]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:   7%|██▋                                      | 1/15 [00:01<00:16,  1.19s/it, curr_train_loss=0.92692101, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  13%|█████▍                                   | 2/15 [00:02<00:15,  1.19s/it, curr_train_loss=0.91570485, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  20%|████████▏                                | 3/15 [00:03<00:14,  1.18s/it, curr_train_loss=0.91466242, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  27%|██████████▉                              | 4/15 [00:04<00:12,  1.17s/it, curr_train_loss=0.92257965, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  33%|█████████████▋                           | 5/15 [00:05<00:11,  1.18s/it, curr_train_loss=0.91119558, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  40%|████████████████▍                        | 6/15 [00:07<00:10,  1.18s/it, curr_train_loss=0.90171254, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  47%|███████████████████▏                     | 7/15 [00:08<00:09,  1.23s/it, curr_train_loss=0.89872617, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  53%|█████████████████████▊                   | 8/15 [00:09<00:08,  1.24s/it, curr_train_loss=0.92767555, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  60%|████████████████████████▌                | 9/15 [00:10<00:07,  1.24s/it, curr_train_loss=0.90298122, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  67%|██████████████████████████▋             | 10/15 [00:12<00:06,  1.25s/it, curr_train_loss=0.89979428, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  73%|█████████████████████████████▎          | 11/15 [00:13<00:04,  1.23s/it, curr_train_loss=0.91023231, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  80%|████████████████████████████████        | 12/15 [00:14<00:03,  1.22s/it, curr_train_loss=0.90807855, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]:  87%|██████████████████████████████████▋     | 13/15 [00:15<00:02,  1.21s/it, curr_train_loss=0.89732885, val_loss=0.90599823]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/100]: 100%|████████████████████████████████████████| 15/15 [00:17<00:00,  1.16s/it, curr_train_loss=0.90487850, val_loss=0.90599823]
# Shape of encoder torch.Size([1256, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [2/100]: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.08it/s, curr_val_loss=0.88321960]
# Shape of encoder torch.Size([1000, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:   0%|                                                                                                  | 0/15 [00:00<?, ?it/s]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:   7%|██▋                                      | 1/15 [00:01<00:16,  1.18s/it, curr_train_loss=0.90115565, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  13%|█████▍                                   | 2/15 [00:02<00:15,  1.18s/it, curr_train_loss=0.89707845, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  20%|████████▏                                | 3/15 [00:03<00:14,  1.19s/it, curr_train_loss=0.90155637, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  27%|██████████▉                              | 4/15 [00:04<00:13,  1.19s/it, curr_train_loss=0.88722730, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  33%|█████████████▋                           | 5/15 [00:05<00:11,  1.18s/it, curr_train_loss=0.89117211, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  40%|████████████████▍                        | 6/15 [00:07<00:10,  1.18s/it, curr_train_loss=0.89569604, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  47%|███████████████████▏                     | 7/15 [00:08<00:09,  1.18s/it, curr_train_loss=0.89573646, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  53%|█████████████████████▊                   | 8/15 [00:09<00:08,  1.18s/it, curr_train_loss=0.88665211, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  60%|████████████████████████▌                | 9/15 [00:10<00:07,  1.18s/it, curr_train_loss=0.88788015, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  67%|██████████████████████████▋             | 10/15 [00:11<00:05,  1.18s/it, curr_train_loss=0.88152868, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  73%|█████████████████████████████▎          | 11/15 [00:12<00:04,  1.18s/it, curr_train_loss=0.88190567, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  80%|████████████████████████████████        | 12/15 [00:14<00:03,  1.18s/it, curr_train_loss=0.88677526, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/100]:  87%|██████████████████████████████████▋     | 13/15 [00:15<00:02,  1.19s/it, curr_train_loss=0.89718926, val_loss=0.88321960]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# ...
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [98/100]:  80%|███████████████████████████████▏       | 12/15 [00:13<00:03,  1.16s/it, curr_train_loss=0.57097453, val_loss=0.48715234]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [98/100]:  87%|█████████████████████████████████▊     | 13/15 [00:15<00:02,  1.16s/it, curr_train_loss=0.56824476, val_loss=0.48715234]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [98/100]: 100%|███████████████████████████████████████| 15/15 [00:16<00:00,  1.10s/it, curr_train_loss=0.57392311, val_loss=0.48715234]
# Shape of encoder torch.Size([1256, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [98/100]: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.60it/s, curr_val_loss=0.48242092]
# Shape of encoder torch.Size([1000, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:   0%|                                                                                                 | 0/15 [00:00<?, ?it/s]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:   7%|██▋                                     | 1/15 [00:01<00:16,  1.16s/it, curr_train_loss=0.56653702, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  13%|█████▎                                  | 2/15 [00:02<00:15,  1.15s/it, curr_train_loss=0.57189411, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  20%|████████                                | 3/15 [00:03<00:13,  1.17s/it, curr_train_loss=0.56688613, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  27%|██████████▋                             | 4/15 [00:04<00:12,  1.16s/it, curr_train_loss=0.56703335, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  33%|█████████████▎                          | 5/15 [00:05<00:11,  1.16s/it, curr_train_loss=0.56884211, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  40%|████████████████                        | 6/15 [00:06<00:10,  1.16s/it, curr_train_loss=0.56345004, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  47%|██████████████████▋                     | 7/15 [00:08<00:09,  1.16s/it, curr_train_loss=0.56651366, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  53%|█████████████████████▎                  | 8/15 [00:09<00:08,  1.16s/it, curr_train_loss=0.56863129, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  60%|████████████████████████                | 9/15 [00:10<00:06,  1.16s/it, curr_train_loss=0.56510210, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  67%|██████████████████████████             | 10/15 [00:11<00:05,  1.16s/it, curr_train_loss=0.57136798, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  73%|████████████████████████████▌          | 11/15 [00:12<00:04,  1.16s/it, curr_train_loss=0.56477112, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  80%|███████████████████████████████▏       | 12/15 [00:13<00:03,  1.16s/it, curr_train_loss=0.56653744, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]:  87%|█████████████████████████████████▊     | 13/15 [00:15<00:02,  1.16s/it, curr_train_loss=0.56789535, val_loss=0.48242092]
# Shape of encoder torch.Size([4096, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [99/100]: 100%|███████████████████████████████████████| 15/15 [00:16<00:00,  1.11s/it, curr_train_loss=0.56820393, val_loss=0.48242092]
# Shape of encoder torch.Size([1256, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [99/100]: 100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  4.57it/s, curr_val_loss=0.48520216]
# Shape of encoder torch.Size([1000, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Finished training!

# %% [markdown]
# Once trained, let's have a look at the reconstructed validation images (If you have not already looked at them in TensorBoard).

# %%
reconstructions = autoencoder.getReconstructions(unlabled_val_loader)
for i in range(64):
    plt.subplot(8,8,i+1)
    plt.axis('off')
    plt.imshow(reconstructions[i], cmap='gray', interpolation='none')
    
plt.tight_layout()
# Out:
# Shape of encoder torch.Size([1000, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )

# %% [markdown]
# # 4. Transfer Learning
#
# ## 4.1 The pretrained Classifier
#
# Now we initialize another classifier but this time with the pretrained encoder.

# %%
from exercise_code.models import Classifier
from copy import deepcopy

hparams = {}
########################################################################
# TODO: Define your hyperparameters here!                             #
########################################################################
hparams = {
            "epochs": 75,
            "batch_size": 20,
            "hidden_dim": 200,
            "device": torch.device("cpu"),
            "learning_rate": 0.01
          }


########################################################################
#                           END OF YOUR CODE                           #
########################################################################

encoder_pretrained_copy = deepcopy(encoder_pretrained)
classifier_pretrained = Classifier(hparams, encoder_pretrained_copy).to(device)

# %% [markdown]
# Let's define another trainer that will utilize the pretrained classifier, allowing us to compare its performance with the classifier trained only on the labeled data. To achieve a reasonable result, you may need to optimize the parameters you defined earlier.

# %%
# Creat a tensorboard logger.
# NOTE: In order to see the logs, run the following command in the terminal: tensorboard --logdir=./
# Also, in order to reset the logs, delete the logs folder MANUALLY.
# Pay attention that if you run this cell mutltiple times, the pretrained_encoder
# is not reset, and will keep training from where it stopped. Thus, it could overfit.

path = os.path.join('logs', 'pretrained_cls_logs')
num_of_runs = len(os.listdir(path)) if os.path.exists(path) else 0
path = os.path.join(path, f'run_{num_of_runs + 1}')
tb_logger = SummaryWriter(path)

batch_size = hparams.get('batch_size', 16)
labled_train_loader = torch.utils.data.DataLoader(train_100_dataset, batch_size=batch_size, shuffle=True)
labled_val_loader = torch.utils.data.DataLoader(val_100_dataset, batch_size=batch_size, shuffle=False)

epochs = hparams.get('epochs', 20)
loss_func = nn.CrossEntropyLoss() # The loss function we use for classification.
train_classifier(classifier_pretrained, labled_train_loader, labled_val_loader, loss_func, tb_logger, epochs=epochs, name='Pretrained')

print("Finished training!")
# Out:
# Training Epoch [1/75]:  20%|████████▌                                  | 1/5 [00:00<00:00,  8.35it/s, curr_train_loss=2.28698146, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/75]:  60%|█████████████████████████▊                 | 3/5 [00:00<00:00,  7.76it/s, curr_train_loss=2.30578649, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [1/75]: 100%|███████████████████████████████████████████| 5/5 [00:00<00:00,  7.62it/s, curr_train_loss=2.35051241, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [1/75]:   0%|                                                                             | 0/5 [00:00<?, ?it/s, val_loss=2.02804065]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [1/75]:  20%|█████████████▊                                                       | 1/5 [00:00<00:00,  7.82it/s, val_loss=2.21768951]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [1/75]:  40%|███████████████████████████▌                                         | 2/5 [00:00<00:00,  7.63it/s, val_loss=2.16045062]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [1/75]:  60%|█████████████████████████████████████████▍                           | 3/5 [00:00<00:00,  7.66it/s, val_loss=2.21031153]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [1/75]:  80%|███████████████████████████████████████████████████████▏             | 4/5 [00:00<00:00,  7.89it/s, val_loss=2.25620928]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [1/75]: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  7.78it/s, val_loss=2.25620928]
# Training Epoch [2/75]:   0%|                                                   | 0/5 [00:00<?, ?it/s, curr_train_loss=2.09663153, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/75]:  20%|████████▌                                  | 1/5 [00:00<00:00,  7.92it/s, curr_train_loss=2.08894300, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/75]:  40%|█████████████████▏                         | 2/5 [00:00<00:00,  7.62it/s, curr_train_loss=2.10427229, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/75]:  60%|█████████████████████████▊                 | 3/5 [00:00<00:00,  7.49it/s, curr_train_loss=2.12878782, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/75]:  80%|██████████████████████████████████▍        | 4/5 [00:00<00:00,  7.46it/s, curr_train_loss=2.16487226, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [2/75]: 100%|███████████████████████████████████████████| 5/5 [00:00<00:00,  7.48it/s, curr_train_loss=2.16487226, val_loss=0.00000000]
# Validation Epoch [2/75]:   0%|                                                                             | 0/5 [00:00<?, ?it/s, val_loss=1.94781554]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [2/75]:  20%|█████████████▊                                                       | 1/5 [00:00<00:00,  8.18it/s, val_loss=2.13036638]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [2/75]:  40%|███████████████████████████▌                                         | 2/5 [00:00<00:00,  7.91it/s, val_loss=2.09145113]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [2/75]:  60%|█████████████████████████████████████████▍                           | 3/5 [00:00<00:00,  7.80it/s, val_loss=2.12003419]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [2/75]:  80%|███████████████████████████████████████████████████████▏             | 4/5 [00:00<00:00,  7.79it/s, val_loss=2.15286562]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [2/75]: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  7.81it/s, val_loss=2.15286562]
# Training Epoch [3/75]:   0%|                                                   | 0/5 [00:00<?, ?it/s, curr_train_loss=2.02216482, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/75]:  20%|████████▌                                  | 1/5 [00:00<00:00,  7.92it/s, curr_train_loss=1.99117351, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/75]:  40%|█████████████████▏                         | 2/5 [00:00<00:00,  7.57it/s, curr_train_loss=1.98828224, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/75]:  60%|█████████████████████████▊                 | 3/5 [00:00<00:00,  7.55it/s, curr_train_loss=2.04157427, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/75]:  80%|██████████████████████████████████▍        | 4/5 [00:00<00:00,  7.38it/s, curr_train_loss=2.05068920, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [3/75]: 100%|███████████████████████████████████████████| 5/5 [00:00<00:00,  7.49it/s, curr_train_loss=2.05068920, val_loss=0.00000000]
# Validation Epoch [3/75]:   0%|                                                                             | 0/5 [00:00<?, ?it/s, val_loss=1.90271509]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [3/75]:  20%|█████████████▊                                                       | 1/5 [00:00<00:00,  8.15it/s, val_loss=2.06177086]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [3/75]:  40%|███████████████████████████▌                                         | 2/5 [00:00<00:00,  7.79it/s, val_loss=2.03079180]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [3/75]:  60%|█████████████████████████████████████████▍                           | 3/5 [00:00<00:00,  7.71it/s, val_loss=2.06554064]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [3/75]:  80%|███████████████████████████████████████████████████████▏             | 4/5 [00:00<00:00,  7.67it/s, val_loss=2.11154726]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [3/75]: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  7.67it/s, val_loss=2.11154726]
# Training Epoch [4/75]:   0%|                                                   | 0/5 [00:00<?, ?it/s, curr_train_loss=2.04703069, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [4/75]:  20%|████████▌                                  | 1/5 [00:00<00:00,  7.91it/s, curr_train_loss=1.96951342, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [4/75]:  40%|█████████████████▏                         | 2/5 [00:00<00:00,  7.67it/s, curr_train_loss=1.91640778, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [4/75]:  60%|█████████████████████████▊                 | 3/5 [00:00<00:00,  7.61it/s, curr_train_loss=1.92099077, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [4/75]:  80%|██████████████████████████████████▍        | 4/5 [00:00<00:00,  7.47it/s, curr_train_loss=1.95389481, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [4/75]: 100%|███████████████████████████████████████████| 5/5 [00:00<00:00,  7.50it/s, curr_train_loss=1.95389481, val_loss=0.00000000]
# Validation Epoch [4/75]:   0%|                                                                             | 0/5 [00:00<?, ?it/s, val_loss=1.92098165]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [4/75]:  20%|█████████████▊                                                       | 1/5 [00:00<00:00,  8.14it/s, val_loss=2.02916646]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [4/75]:  40%|███████████████████████████▌                                         | 2/5 [00:00<00:00,  7.95it/s, val_loss=2.00132386]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [4/75]:  60%|█████████████████████████████████████████▍                           | 3/5 [00:00<00:00,  7.78it/s, val_loss=2.03377408]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [4/75]:  80%|███████████████████████████████████████████████████████▏             | 4/5 [00:00<00:00,  7.56it/s, val_loss=2.06661267]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [4/75]: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  7.60it/s, val_loss=2.06661267]
# Training Epoch [5/75]:   0%|                                                   | 0/5 [00:00<?, ?it/s, curr_train_loss=1.91268563, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [5/75]:  20%|████████▌                                  | 1/5 [00:00<00:00,  7.73it/s, curr_train_loss=2.00255120, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [5/75]:  40%|█████████████████▏                         | 2/5 [00:00<00:00,  7.30it/s, curr_train_loss=1.95587369, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [5/75]:  60%|█████████████████████████▊                 | 3/5 [00:00<00:00,  7.34it/s, curr_train_loss=1.91344967, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [5/75]:  80%|██████████████████████████████████▍        | 4/5 [00:00<00:00,  7.39it/s, curr_train_loss=1.90689015, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [5/75]: 100%|███████████████████████████████████████████| 5/5 [00:00<00:00,  7.37it/s, curr_train_loss=1.90689015, val_loss=0.00000000]
# Validation Epoch [5/75]:   0%|                                                                             | 0/5 [00:00<?, ?it/s, val_loss=1.80294001]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [5/75]:  20%|█████████████▊                                                       | 1/5 [00:00<00:00,  7.97it/s, val_loss=1.92822045]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [5/75]:  40%|███████████████████████████▌                                         | 2/5 [00:00<00:00,  7.80it/s, val_loss=1.95167482]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [5/75]:  60%|█████████████████████████████████████████▍                           | 3/5 [00:00<00:00,  7.76it/s, val_loss=1.96776763]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [5/75]:  80%|███████████████████████████████████████████████████████▏             | 4/5 [00:00<00:00,  7.79it/s, val_loss=1.99109271]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [5/75]: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  7.76it/s, val_loss=1.99109271]
# Training Epoch [6/75]:   0%|                                                   | 0/5 [00:00<?, ?it/s, curr_train_loss=2.08007836, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [6/75]:  20%|████████▌                                  | 1/5 [00:00<00:00,  7.79it/s, curr_train_loss=1.87568980, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [6/75]:  40%|█████████████████▏                         | 2/5 [00:00<00:00,  7.64it/s, curr_train_loss=1.90184104, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [6/75]:  60%|█████████████████████████▊                 | 3/5 [00:00<00:00,  7.75it/s, curr_train_loss=1.89866042, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [6/75]:  80%|██████████████████████████████████▍        | 4/5 [00:00<00:00,  7.66it/s, curr_train_loss=1.86166255, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [6/75]: 100%|███████████████████████████████████████████| 5/5 [00:00<00:00,  7.54it/s, curr_train_loss=1.86166255, val_loss=0.00000000]
# Validation Epoch [6/75]:   0%|                                                                             | 0/5 [00:00<?, ?it/s, val_loss=1.87863886]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [6/75]:  20%|█████████████▊                                                       | 1/5 [00:00<00:00,  8.10it/s, val_loss=1.94830066]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [6/75]:  40%|███████████████████████████▌                                         | 2/5 [00:00<00:00,  7.82it/s, val_loss=1.94617331]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [6/75]:  60%|█████████████████████████████████████████▍                           | 3/5 [00:00<00:00,  7.82it/s, val_loss=1.92653599]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [6/75]:  80%|███████████████████████████████████████████████████████▏             | 4/5 [00:00<00:00,  7.91it/s, val_loss=1.95331013]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [6/75]: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  7.83it/s, val_loss=1.95331013]
# Training Epoch [7/75]:   0%|                                                   | 0/5 [00:00<?, ?it/s, curr_train_loss=1.65516317, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
# ...
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [74/75]:  20%|████████▍                                 | 1/5 [00:00<00:00,  7.87it/s, curr_train_loss=0.43825790, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [74/75]:  40%|████████████████▊                         | 2/5 [00:00<00:00,  7.68it/s, curr_train_loss=0.41154564, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [74/75]:  60%|█████████████████████████▏                | 3/5 [00:00<00:00,  7.55it/s, curr_train_loss=0.44802096, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [74/75]:  80%|█████████████████████████████████▌        | 4/5 [00:00<00:00,  7.55it/s, curr_train_loss=0.44110991, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [74/75]: 100%|██████████████████████████████████████████| 5/5 [00:00<00:00,  7.53it/s, curr_train_loss=0.44110991, val_loss=0.00000000]
# Validation Epoch [74/75]:   0%|                                                                            | 0/5 [00:00<?, ?it/s, val_loss=1.37478900]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [74/75]:  20%|█████████████▌                                                      | 1/5 [00:00<00:00,  8.14it/s, val_loss=1.32079345]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [74/75]:  40%|███████████████████████████▏                                        | 2/5 [00:00<00:00,  7.92it/s, val_loss=1.34898559]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [74/75]:  60%|████████████████████████████████████████▊                           | 3/5 [00:00<00:00,  7.85it/s, val_loss=1.18479759]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [74/75]:  80%|██████████████████████████████████████████████████████▍             | 4/5 [00:00<00:00,  7.88it/s, val_loss=1.13730199]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [74/75]: 100%|████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  7.80it/s, val_loss=1.13730199]
# Training Epoch [75/75]:   0%|                                                  | 0/5 [00:00<?, ?it/s, curr_train_loss=0.35624778, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [75/75]:  20%|████████▍                                 | 1/5 [00:00<00:00,  7.81it/s, curr_train_loss=0.52347258, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [75/75]:  40%|████████████████▊                         | 2/5 [00:00<00:00,  7.62it/s, curr_train_loss=0.55029662, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [75/75]:  60%|█████████████████████████▏                | 3/5 [00:00<00:00,  7.46it/s, curr_train_loss=0.48450595, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [75/75]:  80%|█████████████████████████████████▌        | 4/5 [00:00<00:00,  7.34it/s, curr_train_loss=0.46481866, val_loss=0.00000000]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Training Epoch [75/75]: 100%|██████████████████████████████████████████| 5/5 [00:00<00:00,  7.38it/s, curr_train_loss=0.46481866, val_loss=0.00000000]
# Validation Epoch [75/75]:   0%|                                                                            | 0/5 [00:00<?, ?it/s, val_loss=1.30376232]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [75/75]:  20%|█████████████▌                                                      | 1/5 [00:00<00:00,  8.35it/s, val_loss=1.09436989]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [75/75]:  40%|███████████████████████████▏                                        | 2/5 [00:00<00:00,  7.92it/s, val_loss=1.20069023]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [75/75]:  60%|████████████████████████████████████████▊                           | 3/5 [00:00<00:00,  7.79it/s, val_loss=1.08053997]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [75/75]:  80%|██████████████████████████████████████████████████████▍             | 4/5 [00:00<00:00,  7.75it/s, val_loss=1.02434609]
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Epoch [75/75]: 100%|████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00,  7.73it/s, val_loss=1.02434609]
# Finished training!

# %% [markdown]
# Let's have a look at the validation accuracy of the two different classifiers and compare them. And don't forget that you can also monitor your training in TensorBoard.
#
# We will only look at the test accuracy and compare our two classifiers with respect to that in the very end.

# %%
val_acc_scracth = classifier.getAcc(labled_val_loader)[1]*100
color = 'green' if val_acc_scracth > 55 else 'red'
print(f"Validation accuracy when training from scratch: {bcolors.colorize(color, val_acc_scracth)}%")

val_acc_pretrained = classifier_pretrained.getAcc(labled_val_loader)[1]*100
color = 'green' if val_acc_pretrained > 55 else 'red'
print(f"Validation accuracy with pretraining: {bcolors.colorize(color, val_acc_pretrained)}%")
# Out:
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation accuracy when training from scratch: 49.0%
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation accuracy with pretraining: 70.0%

# %% [markdown]
# Now that everything is working, feel free to play around with different architectures. As you've seen, it's quite easy to define your model or do adpations there.
#
# To pass this submission, you will need to achieve an accuracy of **55%**.

# %% [markdown]
# # Save your model & Report Test Accuracy
#
# When you are finally done with your **hyperparameter tuning**, achieved **at least 55% validation accuracy** and are happy with your final model, you can save it here.
#
# Before that, please check again whether the number of parameters is below 5 Mio and the file size is below 20 MB.
#
# Once your final model is saved, we'll finally report the test accuracy.

# %%
from exercise_code.Util import test_and_save
test_dl = torch.utils.data.DataLoader(test_100_dataset, batch_size=4, shuffle=False)

test_acc = classifier.getAcc(test_dl)[1]*100
color = 'green' if test_acc > 55 else 'red'
print(f"Test accuracy when training from scratch: {bcolors.colorize(color, test_acc)}%")

test_acc = classifier_pretrained.getAcc(test_dl)[1]*100
color = 'green' if test_acc > 55 else 'red'
print(f"Test accuracy with pretraining: {bcolors.colorize(color, test_acc)}%")

test_and_save(classifier_pretrained, labled_val_loader, test_dl)
# Out:
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Test accuracy when training from scratch: 53.0%
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Test accuracy with pretraining: 63.0%
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([20, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Validation Accuracy: 71.0%
# # Paramters: Your model has 0.446 mio. params.
# Size: Great! Your model size is 3.6 MB and is less than 20 MB.
# Your model has been saved and is ready to be submitted.
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )
# Shape of encoder torch.Size([4, 784])
# encoder Sequential(
#   (0): Linear(in_features=784, out_features=500, bias=True)
#   (1): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=500, out_features=100, bias=True)
#   (5): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=100, out_features=20, bias=True)
#   (9): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
# )

# %%
# Now zip the folder for upload
from exercise_code.submit import submit_exercise

submit_exercise('../output/exercise_08')

# %% [markdown]
# Congratulations on completing your first autoencoder and successfully transferring the weights to a classifier! It's remarkable how much easier this process becomes with the power of PyTorch, compared to working with plain NumPy, right?
#
# To complete the exercise, please submit your final model to [our submission portal](https://i2dl.vc.in.tum.de/) - you should be already familiar with the submission procedure. Next, it is time to get started with some more complex neural networks and tasks in the upcoming exercises. See you next week!
#
# # Submission Goals
#
# - Goal: Successfully implement a fully connected autoencoder for MNIST with Pytorch and transfer the encoder weights to a classifier.
#
# - Passing Criteria: There are no unit tests that check specific components of your code. The only thing that's required to pass the submission, is your model to reach at least **55% accuracy** on __our__ test dataset. The submission system will show you a number between 0 and 100 which corresponds to your accuracy.
#
# - Submission start: __June 15, 2023 10:00__
# - Submission deadline : __June 21, 2023 15:59__
# - You can make **$\infty$** submissions until the deadline. Your __best submission__ will be considered for the bonus.

# %% [markdown]
# # [Exercise Review](https://forms.gle/9SYivCPQZdktRDS29)
#
# We are always interested in your opinion. Now that you have finished this exercise, we would like you to give us some feedback about the time required to finish the submission and/or work through the notebooks. Please take the short time to fill out our [review form](https://forms.gle/9SYivCPQZdktRDS29) for this exercise so that we can do better next time! :)
